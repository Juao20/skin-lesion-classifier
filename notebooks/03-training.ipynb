# %%
import sys
import os

repo_root = "/kaggle/input/datasets/juaoafa/repogit"  # remplace par le chemin trouvé ci-dessus

# Vide le cache d'import au cas où une session précédente a chargé une vieille version
for mod in list(sys.modules):
    if mod == "src" or mod.startswith("src."):
        del sys.modules[mod]

sys.path.insert(0, repo_root)

# Important : /kaggle/input est en lecture seule.
# On se place dans /kaggle/working (seul dossier inscriptible) pour que
# les checkpoints puissent y être écrits.
os.chdir("/kaggle/working")

# train.py utilise argparse ; on simule les arguments en ligne de commande
sys.argv = ["train.py", "--config", f"{repo_root}/configs/baseline.yaml"]

from src.train import main
main()
# Out:
# Device: cuda
# model.safetensors:   0%|          | 0.00/102M [00:00<?, ?B/s]
# Epoch  1/20 | train_loss 1.8739 | val_loss 1.5131 | bal_acc 0.3010 | macro_f1 0.2808 | recall_mel 0.6486
#   -> nouveau meilleur macro_f1 0.2808, sauvé dans checkpoints/best_model.pt
# Epoch  2/20 | train_loss 1.5285 | val_loss 1.0963 | bal_acc 0.5134 | macro_f1 0.4278 | recall_mel 0.4505
#   -> nouveau meilleur macro_f1 0.4278, sauvé dans checkpoints/best_model.pt
# Epoch  3/20 | train_loss 1.1455 | val_loss 0.9338 | bal_acc 0.5630 | macro_f1 0.4843 | recall_mel 0.4640
#   -> nouveau meilleur macro_f1 0.4843, sauvé dans checkpoints/best_model.pt
# Epoch  4/20 | train_loss 1.0063 | val_loss 0.8865 | bal_acc 0.6182 | macro_f1 0.4926 | recall_mel 0.4369
#   -> nouveau meilleur macro_f1 0.4926, sauvé dans checkpoints/best_model.pt
# Epoch  5/20 | train_loss 0.8902 | val_loss 0.7173 | bal_acc 0.6229 | macro_f1 0.5610 | recall_mel 0.5315
#   -> nouveau meilleur macro_f1 0.5610, sauvé dans checkpoints/best_model.pt
# Epoch  6/20 | train_loss 0.8277 | val_loss 0.8173 | bal_acc 0.6583 | macro_f1 0.5348 | recall_mel 0.5495
# Epoch  7/20 | train_loss 0.8021 | val_loss 0.6800 | bal_acc 0.6580 | macro_f1 0.5739 | recall_mel 0.5360
#   -> nouveau meilleur macro_f1 0.5739, sauvé dans checkpoints/best_model.pt
# Epoch  8/20 | train_loss 0.7457 | val_loss 0.7189 | bal_acc 0.6881 | macro_f1 0.5714 | recall_mel 0.4234
# Epoch  9/20 | train_loss 0.7039 | val_loss 0.6843 | bal_acc 0.7014 | macro_f1 0.6016 | recall_mel 0.4595
#   -> nouveau meilleur macro_f1 0.6016, sauvé dans checkpoints/best_model.pt
# Epoch 10/20 | train_loss 0.6492 | val_loss 0.6605 | bal_acc 0.6602 | macro_f1 0.5933 | recall_mel 0.4640
# Epoch 11/20 | train_loss 0.6561 | val_loss 0.6564 | bal_acc 0.6887 | macro_f1 0.6099 | recall_mel 0.5225
#   -> nouveau meilleur macro_f1 0.6099, sauvé dans checkpoints/best_model.pt
# Epoch 12/20 | train_loss 0.5908 | val_loss 0.5842 | bal_acc 0.6824 | macro_f1 0.6387 | recall_mel 0.4685
#   -> nouveau meilleur macro_f1 0.6387, sauvé dans checkpoints/best_model.pt
# Epoch 13/20 | train_loss 0.5797 | val_loss 0.6457 | bal_acc 0.6818 | macro_f1 0.6120 | recall_mel 0.4910
# Epoch 14/20 | train_loss 0.5706 | val_loss 0.5914 | bal_acc 0.6924 | macro_f1 0.6417 | recall_mel 0.4054
#   -> nouveau meilleur macro_f1 0.6417, sauvé dans checkpoints/best_model.pt
# Epoch 15/20 | train_loss 0.5580 | val_loss 0.6753 | bal_acc 0.6760 | macro_f1 0.5841 | recall_mel 0.4640
# Epoch 16/20 | train_loss 0.5376 | val_loss 0.6818 | bal_acc 0.6876 | macro_f1 0.5957 | recall_mel 0.4459
# Epoch 17/20 | train_loss 0.5383 | val_loss 0.6640 | bal_acc 0.6822 | macro_f1 0.6097 | recall_mel 0.4595
# Epoch 18/20 | train_loss 0.4910 | val_loss 0.6374 | bal_acc 0.6763 | macro_f1 0.6267 | recall_mel 0.5180
# Epoch 19/20 | train_loss 0.5158 | val_loss 0.6236 | bal_acc 0.6817 | macro_f1 0.6487 | recall_mel 0.5495
#   -> nouveau meilleur macro_f1 0.6487, sauvé dans checkpoints/best_model.pt
# Epoch 20/20 | train_loss 0.4606 | val_loss 0.6265 | bal_acc 0.6804 | macro_f1 0.6465 | recall_mel 0.5135
# Entraînement terminé. Meilleur macro_f1: 0.6487
